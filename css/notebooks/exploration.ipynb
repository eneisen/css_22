# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
features = pd.read_csv(os.path.join('..', 'data', 'features.csv'))
label = pd.read_csv(os.path.join('..', 'data', 'label.csv'))

# %%
features['label'] = label['label']

# %%
features.head()
# Out:
#       y_std   y0__std  y_max    z0_std  y0_min     z_std  y0_max  z_min  \
# 0  0.070711  0.070711    0.7  0.353553     0.1  0.353553     0.2   10.5
# 1  0.152753  0.057735    0.9  0.288675     0.1  0.288675     0.2   10.5
# 2  0.547723  0.173205    1.8  0.244949     0.1  0.244949     0.5   10.5
# 3  0.506952  0.250998    1.8  0.661060    -0.2  0.703562     0.5    9.3
# 4  0.479236  0.320416    1.8  0.857127    -0.4  0.907010     0.5    8.9
#
#      x0_std  z0_min  label
# 0  0.282843     0.8      0
# 1  0.264575     0.8      0
# 2  0.238048     0.8      0
# 3  0.356371    -0.3      0
# 4  0.397073    -0.7      0

# %%
plt.figure(figsize=(17, 10))
#sns.set_context("paper", rc={"axes.labelsize":13})
#sns.set_context("talk", font_scale=1.8)
sns.pairplot(data=features, hue='label')
